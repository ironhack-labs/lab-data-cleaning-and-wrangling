# %%
import pandas as pd
import numpy as np

# %%
numerical = pd.read_csv('numerical.csv')

# %%
pamella = pd.read_csv('pamella.csv')

# %%
# Merge the 'Effective To Date' column with data_df_clean
merged_df = pd.concat([numerical, pamella], axis=1)

# %%
merged_df
# Out:
#       Unnamed: 0  customer_lifetime_value  income  monthly_premium_auto  \
# 0              0              2763.519279   56274                    69
# 1              1              6979.535903       0                    94
# 2              2             12887.431650   48767                   108
# 3              3              7645.861827       0                   106
# 4              4              2813.692575   43836                    73
# ...          ...                      ...     ...                   ...
# 9129        9129             23405.987980   71941                    73
# 9130        9130              3096.511217   21604                    79
# 9131        9131              8163.890428       0                    85
# 9132        9132              7524.442436   21941                    96
# 9133        9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# ...

# %%
new_column_names = {}
for col in merged_df.columns:
    new_col = col.lower().replace(' ', '_')
    new_column_names[col] = new_col

pamella2 = merged_df.rename(columns=new_column_names)

# %%
pamella2
# Out:
#       unnamed:_0  customer_lifetime_value  income  monthly_premium_auto  \
# 0              0              2763.519279   56274                    69
# 1              1              6979.535903       0                    94
# 2              2             12887.431650   48767                   108
# 3              3              7645.861827       0                   106
# 4              4              2813.692575   43836                    73
# ...          ...                      ...     ...                   ...
# 9129        9129             23405.987980   71941                    73
# 9130        9130              3096.511217   21604                    79
# 9131        9131              8163.890428       0                    85
# 9132        9132              7524.442436   21941                    96
# 9133        9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# ...

# %%
pamella2.drop('unnamed:_0', axis=1, inplace=True)

# %%
pamella2
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %% [markdown]
# # 1.We will start with removing outliers. So far, we have discussed different methods to remove outliers. Use the one you feel more comfortable with, define a function for that. Use the function to remove the outliers and apply it to the dataframe.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
numerical = pamella2.select_dtypes(include=['int',"float"])
categorical = pamella2.select_dtypes(include=["object"])

numerical
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
pamella2.drop(['customer_id','year','customer'], axis=1, inplace=True)

# %%
pamella2
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
for col in numerical.columns:
    print(col)
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
    
    ax1.boxplot(numerical[col])
    ax1.set_title(col + " Boxplot")
    
    ax2.hist(numerical[col], bins=20)
    ax2.set_title(col + " Histogram")
    
    ax1.set_ylabel(col)
    ax2.set_xlabel(col)
    
    plt.show()
# Out:
# customer_lifetime_value
# income
# monthly_premium_auto
# months_since_last_claim
# months_since_policy_inception
# number_of_open_complaints
# number_of_policies
# total_claim_amount
# customer_id
# year

# %%
cols_outliers=['customer_lifetime_value','monthly_premium_auto','total_claim_amount']
cols_outliers
# Out:
# ['customer_lifetime_value', 'monthly_premium_auto', 'total_claim_amount']

# %%
def no_outliers(pamella2,cols_outliers):
    for col in cols_outliers:
        iqr = np.percentile(pamella2[col],75)-np.percentile(pamella2[col],25)
        upper_limit = np.percentile(pamella2[col],75) + 1.5*iqr
        pamella3=pamella2[pamella2[col]<upper_limit]
    return pamella3

# %%
pamella3=no_outliers(pamella2,cols_outliers).reset_index()

# %%
pamella3
# Out:
#       index  customer_lifetime_value  income  monthly_premium_auto  \
# 0         0              2763.519279   56274                    69
# 1         2             12887.431650   48767                   108
# 2         3              7645.861827       0                   106
# 3         4              2813.692575   43836                    73
# 4         5              8256.297800   62902                    69
# ...     ...                      ...     ...                   ...
# 8676   9129             23405.987980   71941                    73
# 8677   9130              3096.511217   21604                    79
# 8678   9131              8163.890428       0                    85
# 8679   9132              7524.442436   21941                    96
# 8680   9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# ...

# %%
Y=pamella3["total_claim_amount"]
pamella4=pamella3.drop(["total_claim_amount"],axis=1)

# %%
numerical = pamella4.select_dtypes(include=['int',"float"])
categorical = pamella4.select_dtypes(include=["object"])

for col in numerical.columns:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
    
    ax1.boxplot(numerical[col])
    ax1.set_title(col + " Boxplot")
    
    ax2.hist(numerical[col], bins=20)
    ax2.set_title(col + " Histogram")
    
    ax1.set_ylabel(col)
    ax2.set_xlabel(col)
    
    plt.show()

# %% [markdown]
# # 2.Create a copy of the dataframe for the data wrangling.

# %%
pamella4_wrangling=pamella4.copy()
pamella4_wrangling
# Out:
#       index  customer_lifetime_value  income  monthly_premium_auto  \
# 0         0              2763.519279   56274                    69
# 1         2             12887.431650   48767                   108
# 2         3              7645.861827       0                   106
# 3         4              2813.692575   43836                    73
# 4         5              8256.297800   62902                    69
# ...     ...                      ...     ...                   ...
# 8676   9129             23405.987980   71941                    73
# 8677   9130              3096.511217   21604                    79
# 8678   9131              8163.890428       0                    85
# 8679   9132              7524.442436   21941                    96
# 8680   9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# ...

# %% [markdown]
# # 3.Normalize the continuous variables. You can use any one method you want.

# %%
discrete_cols=[]
continuous_cols=[]

for col in numerical.columns:
    if numerical[col].nunique() <= 20:
        discrete_cols.append(col)
    else:
        continuous_cols.append(col)
continuous_num = numerical[continuous_cols].reset_index()
continuous_num
# Out:
#       level_0  index  customer_lifetime_value  income  monthly_premium_auto  \
# 0           0      0              2763.519279   56274                    69
# 1           1      2             12887.431650   48767                   108
# 2           2      3              7645.861827       0                   106
# 3           3      4              2813.692575   43836                    73
# 4           4      5              8256.297800   62902                    69
# ...       ...    ...                      ...     ...                   ...
# 8676     8676   9129             23405.987980   71941                    73
# 8677     8677   9130              3096.511217   21604                    79
# 8678     8678   9131              8163.890428       0                    85
# 8679     8679   9132              7524.442436   21941                    96
# 8680     8680   9133              2611.836866       0                    77
#
# ...

# %%
discrete_num=numerical[discrete_cols].reset_index()
discrete_num
# Out:
#       index  number_of_open_complaints  number_of_policies
# 0         0                          0                   1
# 1         1                          0                   2
# 2         2                          0                   7
# 3         3                          0                   1
# 4         4                          0                   2
# ...     ...                        ...                 ...
# 8676   8676                          0                   2
# 8677   8677                          0                   1
# 8678   8678                          3                   2
# 8679   8679                          0                   3
# 8680   8680                          0                   1
#
# [8681 rows x 3 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

transformer=MinMaxScaler().fit(continuous_num)
continuous_num_norm=transformer.transform(continuous_num)

continuous_num_norm=pd.DataFrame(continuous_num_norm)
continuous_num_norm.columns=continuous_num.columns
continuous_num_norm
# Out:
#        level_0     index  customer_lifetime_value    income  \
# 0     0.000000  0.000000                 0.013112  0.562847
# 1     0.000115  0.000219                 0.166483  0.487763
# 2     0.000230  0.000328                 0.087076  0.000000
# 3     0.000346  0.000438                 0.013872  0.438443
# 4     0.000461  0.000547                 0.096324  0.629140
# ...        ...       ...                      ...       ...
# 8676  0.999539  0.999562                 0.325833  0.719547
# 8677  0.999654  0.999672                 0.018157  0.216081
# 8678  0.999770  0.999781                 0.094924  0.000000
# 8679  0.999885  0.999891                 0.085237  0.219452
# 8680  1.000000  1.000000                 0.010814  0.000000
#
#       monthly_premium_auto  months_since_last_claim  \
# 0                 0.034043                 0.914286
# 1                 0.200000                 0.514286
# 2                 0.191489                 0.514286
# ...

# %%
numerical=pd.concat([continuous_num_norm,discrete_num], axis=1)
numerical
# Out:
#        level_0     index  customer_lifetime_value    income  \
# 0     0.000000  0.000000                 0.013112  0.562847
# 1     0.000115  0.000219                 0.166483  0.487763
# 2     0.000230  0.000328                 0.087076  0.000000
# 3     0.000346  0.000438                 0.013872  0.438443
# 4     0.000461  0.000547                 0.096324  0.629140
# ...        ...       ...                      ...       ...
# 8676  0.999539  0.999562                 0.325833  0.719547
# 8677  0.999654  0.999672                 0.018157  0.216081
# 8678  0.999770  0.999781                 0.094924  0.000000
# 8679  0.999885  0.999891                 0.085237  0.219452
# 8680  1.000000  1.000000                 0.010814  0.000000
#
#       monthly_premium_auto  months_since_last_claim  \
# 0                 0.034043                 0.914286
# 1                 0.200000                 0.514286
# 2                 0.191489                 0.514286
# ...

# %% [markdown]
# # 4.Encode the categorical variables

# %%
categorical
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1         Nevada       No   Premium  Bachelor         Employed      F
# 2     California       No     Basic  Bachelor       Unemployed      M
# 3     Washington       No     Basic  Bachelor         Employed      M
# 4         Oregon      Yes     Basic  Bachelor         Employed      F
# ...          ...      ...       ...       ...              ...    ...
# 8676  California       No     Basic  Bachelor         Employed      M
# 8677  California      Yes  Extended   College         Employed      F
# 8678  California       No  Extended  Bachelor       Unemployed      M
# 8679  California       No  Extended   College         Employed      M
# 8680  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status     policy_type renew_offer_type  \
# ...

# %% [markdown]
# # 5.The time variable can be useful. Try to transform its data into a useful one. Hint: Day week and month as integers might be useful.

# %%
categorical.dtypes
# Out:
# state                object
# response             object
# coverage             object
# education            object
# employmentstatus     object
# gender               object
# location_code        object
# marital_status       object
# policy_type          object
# renew_offer_type     object
# sales_channel        object
# vehicle_class        object
# vehicle_size         object
# effective_to_date    object
# dtype: object

# %%
categorical['effective_to_date'] = pd.to_datetime(categorical['effective_to_date'])

# %%
categorical['day'] = categorical['effective_to_date'].dt.day
categorical['month'] = categorical['effective_to_date'].dt.month

# %%
categorical['day_of_week_number'] = categorical['effective_to_date'].dt.dayofweek

categorical
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1         Nevada       No   Premium  Bachelor         Employed      F
# 2     California       No     Basic  Bachelor       Unemployed      M
# 3     Washington       No     Basic  Bachelor         Employed      M
# 4         Oregon      Yes     Basic  Bachelor         Employed      F
# ...          ...      ...       ...       ...              ...    ...
# 8676  California       No     Basic  Bachelor         Employed      M
# 8677  California      Yes  Extended   College         Employed      F
# 8678  California       No  Extended  Bachelor       Unemployed      M
# 8679  California       No  Extended   College         Employed      M
# 8680  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status     policy_type renew_offer_type  \
# ...

# %%
for col in categorical.columns:
    print(f"Unique values in column '{col}':")
    print(categorical[col].nunique())

# %%
from sklearn.preprocessing import OneHotEncoder

one_hot_names = []
for col in categorical.columns:
    col_uniques = sorted(categorical[col].astype(str).unique())
    for unique in col_uniques:
        one_hot_names.append(col+"_"+unique)

categorical = pd.DataFrame(OneHotEncoder().fit_transform(categorical.astype(str)).toarray())
categorical.columns = one_hot_names
categorical

# %% [markdown]
# # 6.Since the model will only accept numerical data, check and make sure that every column is numerical, if some are not, change it using encoding.

# %%
X=pd.concat([categorical,numerical], axis=1)
X

# %%
import statsmodels.api as sm
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.3,random_state=90)
model = sm.OLS(y_train,x_train).fit()
predictions = model.predict(x_test)
r2 = r2_score(y_test,predictions)
print("r2 score is: ", r2)

# %%
comparison=pd.concat([y_test,predictions],axis=1)
comparison.columns=["y_test","predictions"]
comparison=comparison.reset_index()
comparison=comparison.drop(["index"],axis=1)
display(pd.DataFrame(comparison))
